# %%
import pandas as pd
import numpy as np
import tldextract

# %%
bs = pd.read_json("./data/sources_credibility.json").T.reset_index()

# %%
bs = bs.rename(columns={"index": "site_url", "2nd type": "type2", "3rd type": "type3"})
bs["type"] = bs["type"].apply(lambda x: x.strip())
bs["type2"] = bs["type2"].apply(lambda x: x.strip())
bs["type3"] = bs["type3"].apply(lambda x: x.strip())
bs.sample(15)
# Out:
#                          site_url       type2       type3  \
# 309        godlikeproductions.com
# 210           dailyoccupation.com        bias
# 589  themuslimissue.wordpress.com  conspiracy
# 116           bigamericannews.com        fake
# 520               remedydaily.com
# 107              awazetribune.com
# 601             therightscoop.com   clickbait
# 135                   bvanews.com        bias        fake
# 126           blacklistednews.com  unreliable
# 140                cbsnews.com.co
# 86            americanthinker.com
# 104                      attn.com   clickbait
# 290              freedomdaily.com
# 358               journal-neo.org
# 578          thegatewaypundit.com  conspiracy  unreliable
#
#                         Source Notes (things to know?)        type
# 309                                                     conspiracy
# 210                                                     conspiracy
# 589                                                           hate
# 116                                                         satire
# 520                                                      clickbait
# 107                                                         satire
# 601  no authors, no history, no about us, unverifia...        fake
# 135  seems like a combination of totally fake and u...  unreliable
# 126                                                      clickbait
# 140                                                           fake
# 86   sites both credible/not credible sources, mix ...        bias
# 104                                                      political
# 290                                                           fake
# 358                                                           bias
# 578                                                           bias

# %%
bs["type_"] = 0
bs["type_"] = bs.apply(lambda x: "0" if (x["type"]=="credible" or x["type2"]=="credible" or x["type3"]=="credible") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0" if (x["type"]=="state" or x["type2"]=="state" or x["type3"]=="state") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.1" if (x["type"]=="political" or x["type2"]=="political" or x["type3"]=="political") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.5" if (x["type"]=="satire" or x["type2"]=="satire" or x["type3"]=="satire") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.5" if (x["type"]=="unknown" or x["type2"]=="unknown" or x["type3"]=="unknown") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.7" if (x["type"]=="bias" or x["type2"]=="bias" or x["type3"]=="bias") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.7" if (x["type"]=="bais" or x["type2"]=="bais" or x["type3"]=="bais") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.8" if (x["type"]=="junksci" or x["type2"]=="junksci" or x["type3"]=="junksci") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.8" if (x["type"]=="hate" or x["type2"]=="hate" or x["type3"]=="hate") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.8" if (x["type"]=="clickbait" or x["type2"]=="clickbait" or x["type3"]=="clickbait") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.9" if (x["type"]=="conspiracy" or x["type2"]=="conspiracy" or x["type3"]=="conspiracy") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "0.9" if (x["type"]=="rumor" or x["type2"]=="rumor" or x["type3"]=="rumor") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "1" if (x["type"]=="unreliable" or x["type2"]=="unreliable" or x["type3"]=="unreliable") else x["type_"], axis=1)
bs["type_"] = bs.apply(lambda x: "1" if (x["type"]=="fake" or x["type2"]=="fake" or x["type3"]=="fake") else x["type_"], axis=1)

# %%
bs["site_url"] = bs["site_url"].apply(lambda x: x.replace(".com", "").replace(".net", "").replace(".info", "").replace(".tv", "").replace(".org", ""))
bs["site_url"] = bs["site_url"].apply(lambda x: x.replace(".co.uk", "").replace(".wordpress", "").replace(".press", "").replace(".news", "").replace(".biz", ""))

# %%
bs.drop(["type"], axis=1, inplace=True)
bs = bs.rename(columns={"type_": "type"})
bs = bs[["site_url", "type"]]

# %%
bs.head()
# Out:
#               site_url type
# 0      100percentfedup  0.7
# 1      21stcenturywire  0.9
# 2          24newsflash    1
# 3           365usanews  0.9
# 4  4threvolutionarywar  0.9

# %%
bs["site_url"]
# Out:
# 0              100percentfedup
# 1              21stcenturywire
# 2                  24newsflash
# 3                   365usanews
# 4          4threvolutionarywar
# 5                       70news
# 6               82.221.129.208
# 7                   Acting-Man
# 8                   Alt-Market
# 9      AmericanKabuki.blogspot
# 10                    AmmoLand
# 11              AutomaticEarth
# 12                       BB4SP
# 13                    BadSquad
# 14            Boilingfrogspost
# 15                BrotherJohnF
# 16          BullionBullsCanada
# 17                     CNSNews
# 18            ComingDepression
# 19                    DProgram
# 20                   DaveJanda
# 21                DeadLineLive
# 22                 DeadlyClear
# 23             DollarVigilante
# 24            Dont-Tread-On.Me
# 25                  Dutchsinse
# 26                     EUTimes
# 27                 EagleRising
# 28                   EbolaHoax
# 29                  Emptywheel
#                 ...
# 688          whydontyoutrythis
# 689                  wikileaks
# 690                  wikileaks
# 691                 wikispooks
# 692               winkprogress
# 693           winningdemocrats
# 694                 witscience
# 695                        wnd
# 696                     wonkie
# 697             world24monitor
# 698          worldcallyoutoday
# 699                 worlddaily
# 700       worldnewsdailyreport
# 701          worldnewspolitics
# 702            worldpoliticsus
# 703                 worldrumor
# 704          worldstoriestoday
# 705                 worldtruth
# 706           worldwidehealthy
# 707                  wtoe5news
# 708          wundergroundmusic
# 709                     www.rt
# 710           yellowhammernews
# 711                 yesimright
# 712                yourfunpage
# 713             yournationnews
# 714               yournewswire
# 715                    zaytung
# 716                  zerohedge
# 717                   zootfeed
# Name: site_url, Length: 718, dtype: object

# %%
bs[bs["site_url"].str.contains("daily")]
# Out:
#                   site_url type
# 83    americanpatriotdaily  0.8
# 158             clashdaily    1
# 170  conservativedailypost    1
# 199          dailybuzzlive    1
# 200            dailycaller  0.8
# 201           dailycurrant  0.5
# 202           dailydiscord  0.5
# 203         dailyheadlines    1
# 204         dailyheadlines    1
# 205               dailyken  0.8
# 206               dailykos  0.8
# 207              dailyleak    1
# 208           dailynewsbin  0.8
# 209       dailynewspolitic  0.5
# 210        dailyoccupation  0.9
# 211          dailypolitics  0.5
# 212       dailypoliticsusa  0.7
# 213            dailysignal  0.7
# 214             dailysquib  0.5
# 215           dailystormer  0.9
# 216      dailytelegraph.au  0.9
# 217              dailywire  0.7
# 268     everythingnewdaily  0.5
# 290           freedomdaily    1
# 312        gopthedailydose    1
# 399       mpidailymagazine    1
# 402      mydailyrelaxation  0.5
# 405              nahadaily  0.5
# 423          newsbuzzdaily    1
# 466       patriotnewsdaily  0.7
# 520            remedydaily  0.8
# 566          thedailybeast  0.1
# 567           thedailymash  0.5
# 568        thedailysheeple  0.9
# 569            thedailywtf  0.5
# 635       usadailypolitics    1
# 636           usadailytime    1
# 645       usapoliticsdaily  0.5
# 678               webdaily    1
# 699             worlddaily  0.5
# 700   worldnewsdailyreport  0.5

# %%
# get input from backend
_input = { "title": "Pakistan oil tanker inferno kills at least 123",
          "subtitle": "Pakistan oil tanker inferno kills at least 123",
          "description": "News",
          "website": "bbc.com",
          "poster": "BBC",
          "url": "http://www.foxn.com/news/world-south-asia-40396036",
          "id": "world-south-asia-40396036" }

# %%
result = bs[bs["site_url"] == tldextract.extract(_input["url"]).domain]#['type'].values[0]
if len(result) == 0:
    result = 0
else:
    result = float(result['type'].values[0])
result
# Out:
# 0
